# %% [markdown]
# # PyFME
#
# This is a gallery of examples for PyFME simulator.

# %%
# !conda install pyfme --channel pyfme --yes --quiet --name python3

# %% [markdown]
# ## [Example 000](examples_as_notebooks/example_000_no_controls.ipynb)

# %% [markdown]
# ## [Example 001](examples_as_notebooks/example_001_stationary_horizontal.ipynb)

# %% [markdown]
# ## [Example 002](examples_as_notebooks/example_002_stationary_descent.ipynb)

# %% [markdown]
# ## [Example 003](examples_as_notebooks/example_003_stationary_ascent.ipynb)

# %% [markdown]
# ## [Example 004](examples_as_notebooks/example_004_stationary_horizontal_turn.ipynb)

# %% [markdown]
# ## [Example 005](examples_as_notebooks/example_005_stationary_turn_during_ascent.ipynb)

# %% [markdown]
# ## [Example 006](examples_as_notebooks/example_006_elevator_doublet.ipynb)

# %% [markdown]
# ## [Example 007](examples_as_notebooks/example_007_rudder_doublet.ipynb)

# %% [markdown]
# ## [Example 008](examples_as_notebooks/example_008_ailerons_doublet.ipynb)

# %% [markdown]
# ## [Example 009](examples_as_notebooks/example_009_elev_aile_rud_doublet.ipynb)
